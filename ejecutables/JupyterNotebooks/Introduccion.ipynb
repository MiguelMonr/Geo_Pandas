# %%
import geopandas as gpd
import os

# %%
prueba = gpd.read_file('/Users/miguela.monreal/Desktop/GeoPandas/ejecutables/JupyterNotebooks/794551067260_s/conjunto_de_datos/c1206_ii.shp')
prueba
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/miguela.monreal/Desktop/GeoPandas/ejecutables/JupyterNotebooks/Introduccion.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/miguela.monreal/Desktop/GeoPandas/ejecutables/JupyterNotebooks/Introduccion.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> prueba = gpd.read_file('/root/Geo_Pandas/794551067260_s/conjunto_de_datos/c1206_ii.shp')
#       <a href='vscode-notebook-cell:/Users/miguela.monreal/Desktop/GeoPandas/ejecutables/JupyterNotebooks/Introduccion.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> prueba
#
# NameError: name 'gpd' is not defined

# %%
#Prueba 2

archivo = "v1206_ii.shp"

path_absoluto = os.path.abspath(archivo)

print(path_absoluto)
# Out:
# /root/Geo_Pandas/v1206_ii.shp

# %%
prueba.plot()
# Out:
# <Axes: >
