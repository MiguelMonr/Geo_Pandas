# %% [markdown]
# # Tarea

# %% [markdown]
# Dentro de esta carpeta se encuentra un directorio llamado "escuelas_privadas.geojson". Tendras que realizar la lectura, graficas y analisis de alguna de las alcalidas.

# %% [markdown]
# Paso 1. Guarda el geojson en un dataframe e imprimelo.

# %%
#Importo las bibliotecas necesarias
import geopandas as gpd
import geodatasets as gds
from shapely.geometry import MultiPoint
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
#Leo el archivo
df = gpd.read_file('escuelas_privadas.geojson')
#Lo imprimo
df
# Out:
#                                                 nombre  \
# 0                                CENDI PART SEDI LOMAS
# 1                                     ARMONIA INFANTIL
# 2                  CENDI PART. COLEGIO DE LAS BALEARES
# 3                     CENDI PART COLEGIO CIBELES, S.C.
# 4           CENTRO DE DESARROLLO INFANTIL KINDERGARDEN
# ...                                                ...
# 3654                                  ARMONIA INFANTIL
# 3655                         CENDI PART MI MUNDO FELIZ
# 3656                    CENDI PART COLEGIO BILBAO S.C.
# 3657  CENDI PART ECOLOGICO DE DESARROLLO INFANTIL S.C.
# 3658                               MUNDO DE LOS PEQUES
#
#                        nivel            turno     sstnmnt  \
# 0                    INICIAL         MATUTINO  Particular
# 1                    INICIAL         MATUTINO  Particular
# 2                    INICIAL  TIEMPO COMPLETO  Particular
# 3                    INICIAL         MATUTINO  Particular
# ...

# %% [markdown]
# Paso 2. Crea otro gdf con solo las escuelas en la delegacion Miguel Hidalgo

# %%
#Filtro por el nombre de la alcaldia y despues lo imprimo
miguel_hidalgo = df[df['alcaldi']=='MIGUEL HIDALGO']
miguel_hidalgo
# Out:
#                                                  nombre  \
# 0                                 CENDI PART SEDI LOMAS
# 11                                  COLEGIO SAN AGUSTIN
# 14                          ESTANCIA INFANTIL PRIMAVERA
# 19    CENTRO DE DESARROLLO INFANTIL UNA SEMILLA DE L...
# 33                                 PROINFANCIA TERESITA
# ...                                                 ...
# 3581  INSTITUTO MEXICANO DE EDUCACIÓN PRIMARIA Y SEC...
# 3620                                  "HUMANITREE HIVE"
# 3621               "SECUNDARIA IL MIO MONDO MONTESSORI"
# 3644                              DR JAIME TORRES BODET
# 3658                                MUNDO DE LOS PEQUES
#
#                        nivel            turno     sstnmnt  \
# 0                    INICIAL         MATUTINO  Particular
# 11                   INICIAL  TIEMPO COMPLETO  Particular
# 14                   INICIAL         MATUTINO  Particular
# ...

# %% [markdown]
# Paso 3. Setea el indice para que ahora sea la colonia

# %%
#Uso la funcion set_index para cambiar el indice
df_colonia = df.set_index('colonia')
df_colonia
# Out:
#                                                                           nombre  \
# colonia
# LOMAS DE CHAPULTEPEC                                       CENDI PART SEDI LOMAS
# SINATEL (AMPL)                                                  ARMONIA INFANTIL
# TIZAPAN_TIZAPAN SAN ANGEL                    CENDI PART. COLEGIO DE LAS BALEARES
# CUAUHTEMOC                                      CENDI PART COLEGIO CIBELES, S.C.
# LEYES DE REFORMA 3A SECCION I         CENTRO DE DESARROLLO INFANTIL KINDERGARDEN
# ...                                                                          ...
# SINATEL (AMPL)                                                  ARMONIA INFANTIL
# VIEJO EJIDO SANTA URSULA COAPA                         CENDI PART MI MUNDO FELIZ
# NUEVA VALLEJO                                     CENDI PART COLEGIO BILBAO S.C.
# TLALPAN CENTRO                  CENDI PART ECOLOGICO DE DESARROLLO INFANTIL S.C.
# ...

# %% [markdown]
# Paso 3. Grafica el dataframe

# %%
#Grafico con plot
df_colonia.plot()
# Out:
# <Axes: >

# %% [markdown]
# Paso 4. Crea dos nuevas columnas en el gdf original que sean para el area y el perimetro, en ellas haz tu calculo de cada una.

# %%
# Cambiar la proyección del GeoDataFrame a EPSG:32615
df = df.to_crs('EPSG:32615')
#Calcular el area y perimetro
df['area'] = df.geometry.area
df['perimetro'] = df.geometry.length
#Imprimo el gdf
df
# Out:
#                                                 nombre  \
# 0                                CENDI PART SEDI LOMAS
# 1                                     ARMONIA INFANTIL
# 2                  CENDI PART. COLEGIO DE LAS BALEARES
# 3                     CENDI PART COLEGIO CIBELES, S.C.
# 4           CENTRO DE DESARROLLO INFANTIL KINDERGARDEN
# ...                                                ...
# 3654                                  ARMONIA INFANTIL
# 3655                         CENDI PART MI MUNDO FELIZ
# 3656                    CENDI PART COLEGIO BILBAO S.C.
# 3657  CENDI PART ECOLOGICO DE DESARROLLO INFANTIL S.C.
# 3658                               MUNDO DE LOS PEQUES
#
#                        nivel            turno     sstnmnt  \
# 0                    INICIAL         MATUTINO  Particular
# 1                    INICIAL         MATUTINO  Particular
# 2                    INICIAL  TIEMPO COMPLETO  Particular
# 3                    INICIAL         MATUTINO  Particular
# ...

# %% [markdown]
# Paso 5. Crea una nueva columna en el gdf del paso 1 que se llame distancia; después escoge una escuela del data frame y que la nueva columna tenga la distancia de todas las escuelas a la que escogiste

# %%
#Seleccionar la coordenada de la escuela
punto = df[df['nombre']=='ARMONIA INFANTIL'].iloc[0]['geometry']

#Calculo la distancia con respecto al punto e imprimo el gdf
df['distancia'] = df['geometry'].distance(punto)
df
# Out:
#                                                 nombre  \
# 0                                CENDI PART SEDI LOMAS
# 1                                     ARMONIA INFANTIL
# 2                  CENDI PART. COLEGIO DE LAS BALEARES
# 3                     CENDI PART COLEGIO CIBELES, S.C.
# 4           CENTRO DE DESARROLLO INFANTIL KINDERGARDEN
# ...                                                ...
# 3654                                  ARMONIA INFANTIL
# 3655                         CENDI PART MI MUNDO FELIZ
# 3656                    CENDI PART COLEGIO BILBAO S.C.
# 3657  CENDI PART ECOLOGICO DE DESARROLLO INFANTIL S.C.
# 3658                               MUNDO DE LOS PEQUES
#
#                        nivel            turno     sstnmnt  \
# 0                    INICIAL         MATUTINO  Particular
# 1                    INICIAL         MATUTINO  Particular
# 2                    INICIAL  TIEMPO COMPLETO  Particular
# 3                    INICIAL         MATUTINO  Particular
# ...

# %% [markdown]
# Paso 6. Realiza una consulta para saber cuales son las 3 escuelas mas lejos del punto que elegiste, debe imprimir solamente el nombre de las escuelas y su distancia al punto

# %%
#Ordeno las escuelas de la mas lejana a la mas cercana 
df_ordenado = df.sort_values(by='distancia',ascending=False)
#Imprimo el nombre y la distancia de las 3 mas lejanas
df_ordenado.head(3)[['nombre','distancia']]
# Out:
#                                       nombre     distancia
# 1107    LICEO UNIVERSITARIO JOSÉ VASCONCELOS  25019.957116
# 3280  "LICEO UNIVERSITARIO JOSÉ VASCONCELOS"  25019.957116
# 233     LICEO UNIVERSITARIO JOSÉ VASCONCELOS  25019.957116

# %% [markdown]
# Paso 7. Agrupa las escuelas por su alcaldia. Una vez hecho eso crea una nueva geometria que "envuelva" a las escuelas de cada alcaldia y graficalos

# %%
# Manejar valores nulos en la columna 'alcaldi'
df['alcaldi'].fillna('Desconocida', inplace=True)

# Agrupar las escuelas por alcaldía y crear una nueva geometría que envuelva las escuelas de cada alcaldía
df_alcaldias = df.groupby('alcaldi')['geometry'].apply(lambda x: gpd.GeoSeries(x).unary_union)

# Crear un nuevo GeoDataFrame con las geometrías resultantes
gdf_alcaldias = gpd.GeoDataFrame(geometry=df_alcaldias)

# Crear un mapeo de colores para cada alcaldía
colormap = plt.cm.get_cmap('viridis', len(df_alcaldias))
colors = range(len(df_alcaldias))

# Graficar el resultado asignando colores diferentes a cada alcaldía
ax1 = df.plot(color='gray', label='Main data')
gdf_alcaldias.plot(ax=ax1, color=colormap(colors), alpha=0.5, legend=True)

# Configurar el aspecto del gráfico
ax1.set_title('Envoltura de Escuelas por Alcaldía')
ax1.set_xlabel('Longitud')
ax1.set_ylabel('Latitud')

# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_11708/1615504973.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = plt.cm.get_cmap('viridis', len(df_alcaldias))

# %% [markdown]
# El paso anterior guardalo como una capa y graficalo en conjunto a la grafica del paso 1

# %%
#Guardo el gdf en un .geojson
gdf_alcaldias.to_file('alcaldias_envelope.geojson', driver='GeoJSON')
#Grafico
ax2 = df.plot(color='gray', label='Main data')
gdf_alcaldias.plot(ax=ax2, color=colormap(colors), alpha=0.5, legend=True)
# Out:
# <Axes: >

# %% [markdown]
# Paso 8. Crea una nueva columna en el gdf inicial llamada 'Calidad_escuela' que imprima un numero aleatorio entre 1 y 10.
# Imprime el gdf

# %%
#Simplemente aplico un random entre 1 y 10 e imprimo
df['Calidad_escuela'] = np.random.randint(1, 11, size=len(df))
df
# Out:
#                                                 nombre  \
# 0                                CENDI PART SEDI LOMAS
# 1                                     ARMONIA INFANTIL
# 2                  CENDI PART. COLEGIO DE LAS BALEARES
# 3                     CENDI PART COLEGIO CIBELES, S.C.
# 4           CENTRO DE DESARROLLO INFANTIL KINDERGARDEN
# ...                                                ...
# 3654                                  ARMONIA INFANTIL
# 3655                         CENDI PART MI MUNDO FELIZ
# 3656                    CENDI PART COLEGIO BILBAO S.C.
# 3657  CENDI PART ECOLOGICO DE DESARROLLO INFANTIL S.C.
# 3658                               MUNDO DE LOS PEQUES
#
#                        nivel            turno     sstnmnt  \
# 0                    INICIAL         MATUTINO  Particular
# 1                    INICIAL         MATUTINO  Particular
# 2                    INICIAL  TIEMPO COMPLETO  Particular
# 3                    INICIAL         MATUTINO  Particular
# ...

# %% [markdown]
# Paso 9. Ahora, plotea el gdf, pero vusalizando la columna 'Calidad escuela'

# %%
# Visualizar el GeoDataFrame con colores basados en la columna 'Calidad_escuela'
ax = df.plot(column='Calidad_escuela', cmap='viridis', legend=True, figsize=(10, 10))

# Configurar el aspecto del gráfico
ax.set_title('Mapa de Calidad de Escuelas')
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')

plt.show()

# %% [markdown]
# Paso 10. Finalmente, plotea en escala de Rojos, en cuantiles de 4 categorias.
# Recuerda que los colores deben de ser claros, inserta una leyenda

# %%
# Visualizar el GeoDataFrame en escala de Rojos con 4 cuantiles
ax = df.plot(column='Calidad_escuela', cmap='Reds', scheme='quantiles', k=4, legend=True, figsize=(10, 10))

# Configurar el aspecto del gráfico
ax.set_title('Mapa de cuantiles')
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
# Out:
# Text(126.30458031299789, 0.5, 'Latitud')
