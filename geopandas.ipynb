# %%
import geopandas as gpd
import os

# %%
url = "http://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_land.geojson"
df = gpd.read_file(url)

# %%
prueba = gpd.read_file('/Users/miguela.monreal/Desktop/GeoPandas/794551067260_s/conjunto_de_datos/c1206_ii.shp')
prueba
# Out:
#     ELEV_NE         FECHA     CAL_POS  \
# 0    1960.0  Febrero 2022  Aproximada
# 1    2140.0  Febrero 2022  Aproximada
# 2    2120.0  Febrero 2022  Aproximada
# 3    2100.0  Febrero 2022  Aproximada
# 4    2080.0  Febrero 2022  Aproximada
# 5    2060.0  Febrero 2022  Aproximada
# 6    1920.0  Febrero 2022  Aproximada
# 7    2040.0  Febrero 2022  Aproximada
# 8    1940.0  Febrero 2022  Aproximada
# 9    1960.0  Febrero 2022  Aproximada
# 10   1980.0  Febrero 2022  Aproximada
# 11   1920.0  Febrero 2022  Aproximada
# 12   2080.0  Febrero 2022  Aproximada
# 13   1940.0  Febrero 2022  Aproximada
# 14   2000.0  Febrero 2022  Aproximada
# 15   2060.0  Febrero 2022  Aproximada
# 16   1960.0  Febrero 2022  Aproximada
# 17   1980.0  Febrero 2022  Aproximada
# 18   2040.0  Febrero 2022  Aproximada
# 19   2000.0  Febrero 2022  Aproximada
# 20   2020.0  Febrero 2022  Aproximada
# 21   2040.0  Febrero 2022  Aproximada
# 22   2020.0  Febrero 2022  Aproximada
# ...

# %%
#Prueba 2

archivo = "v1206_ii.shp"

prueba2 = gpd.read_file(archivo)
prueba2
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open v1206_ii.shx or v1206_ii.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /Users/miguela.monreal/Desktop/GeoPandas/geopandas.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/Users/miguela.monreal/Desktop/GeoPandas/geopandas.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #Prueba 2
#       <a href='vscode-notebook-cell:/Users/miguela.monreal/Desktop/GeoPandas/geopandas.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> archivo = "v1206_ii.shp"
# ...
